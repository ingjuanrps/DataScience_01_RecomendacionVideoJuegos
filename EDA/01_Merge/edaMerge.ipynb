# %% [markdown]
# ### EDA DataFrame Merge.

# %% [markdown]
# #### Importando Librerias.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
# %store -r

# %% [markdown]
# #### Extrayendo y creando mi DataFrame.

# %%
edaMerge = pd.DataFrame(df_merge)
edaMerge.head()
# Out:
#              user_id                   title  items_count  playtime_forever  \
# 0  76561197970982479          Counter-Strike          277                 6
# 1  76561197970982479           Day of Defeat          277                 7
# 2  76561197970982479   Day of Defeat: Source          277              4733
# 3  76561197970982479  Counter-Strike: Source          277              1853
# 4  76561197970982479             Psychonauts          277               333
#
#                  developer  genres  price  anio_lanzamiento  posted  item_id  \
# 0                    Valve  action   9.99              2000    2011     1250
# 1                    Valve  action   4.99              2003    2011     1250
# 2                    Valve  action   9.99              2010    2011     1250
# 3                    Valve  action  19.99              2004    2011     1250
# 4  Double Fine Productions  action   9.99              2005    2011     1250
#
#    recommend  sentiment_analysis
# ...

# %% [markdown]
# #### Información del DataFrame, para ver si el archivo ya no contiene valores nulos.

# %%
edaMerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122043 entries, 0 to 1122042
# Data columns (total 12 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   user_id             1122043 non-null  object
#  1   title               1122043 non-null  object
#  2   items_count         1122043 non-null  int32
#  3   playtime_forever    1122043 non-null  int64
#  4   developer           1122043 non-null  object
#  5   genres              1122043 non-null  object
#  6   price               1122043 non-null  float64
#  7   anio_lanzamiento    1122043 non-null  int64
#  8   posted              1122043 non-null  int32
#  9   item_id             1122043 non-null  int32
#  10  recommend           1122043 non-null  bool
#  11  sentiment_analysis  1122043 non-null  int64
# dtypes: bool(1), float64(1), int32(3), int64(3), object(4)
# memory usage: 82.4+ MB

# %%
edaMerge.isna().sum()
# Out:
# user_id               0
# title                 0
# items_count           0
# playtime_forever      0
# developer             0
# genres                0
# price                 0
# anio_lanzamiento      0
# posted                0
# item_id               0
# recommend             0
# sentiment_analysis    0
# dtype: int64

# %%
color=['blue', 'dimgrey', 'lightblue', 'lightpink', 'violet']
missingno.bar(edaMerge, color= color)
plt.title('Valores Nulos', fontsize= 15)
# Out:
# Text(0.5, 1.0, 'Valores Nulos')

# %% [markdown]
# #### Distribución de registros por recommend.

# %%
recomendado=edaMerge['recommend'].value_counts()
porcentaje=100*edaMerge['recommend'].value_counts(normalize=True)
pd.DataFrame({'Recomendados':recomendado,'Porcentaje':porcentaje.round(2)})
# Out:
#            Recomendados  Porcentaje
# recommend
# True             987772       88.03
# False            134271       11.97

# %% [markdown]
# #### Distribución de registros Sentiment_Analysis.

# %%
recomendado=edaMerge['sentiment_analysis'].value_counts()
porcentaje=100*edaMerge['sentiment_analysis'].value_counts(normalize=True)
pd.DataFrame({'Analisis de Sentimiento':recomendado,'Porcentaje':porcentaje.round(2)})
# Out:
#                     Analisis de Sentimiento  Porcentaje
# sentiment_analysis
# 2                                    640796       57.11
# 0                                    246760       21.99
# 1                                    234487       20.90

# %% [markdown]
# #### Distribución de registros por Posteos.

# %%
recomendado=edaMerge['posted'].value_counts()
porcentaje=100*edaMerge['posted'].value_counts(normalize=True)
pd.DataFrame({'Posteo por año':recomendado,'Porcentaje':porcentaje.round(2)})
# Out:
#         Posteo por año  Porcentaje
# posted
# 2014            514566       45.86
# 2015            425428       37.92
# 2013            143282       12.77
# 2012             25432        2.27
# 2011             12415        1.11
# 2010               920        0.08

# %% [markdown]
# #### Análisis Sentimiento por año.

# %%
sns.countplot(y='posted',data=edaMerge,order=edaMerge['posted'].value_counts().index[0:], hue=edaMerge['sentiment_analysis'])
plt.title('Análisis de Sentimientos por año')
plt.show()
